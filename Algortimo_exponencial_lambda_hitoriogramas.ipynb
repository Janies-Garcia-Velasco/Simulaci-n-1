# %% [markdown]
# <a href="https://colab.research.google.com/github/Janies-Garcia-Velasco/Simulaci-n-1/blob/main/Algortimo_exponencial_lambda_hitoriogramas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random as rnd
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 10
lam = 2  # Usamos lam como lambda

def expo(lam, n):
  L=-1/lam
  lista=[]
  for i in range (n):
    u=rnd.random()
    x=L*np.log(u)
    lista.append(x)
  return lista

# %%
G=expo(0.5,10000)

# %%
media=np.mean(G)

# %%
varianza=np.var(G)

# %%
plt.hist(G)
# Out:
# (array([6.453e+03, 2.262e+03, 8.550e+02, 2.850e+02, 9.200e+01, 3.300e+01,
#         1.200e+01, 5.000e+00, 1.000e+00, 2.000e+00]),
#  array([2.26908191e-04, 2.11035612e+00, 4.22048534e+00, 6.33061456e+00,
#         8.44074377e+00, 1.05508730e+01, 1.26610022e+01, 1.47711314e+01,
#         1.68812606e+01, 1.89913899e+01, 2.11015191e+01]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(G)

# %%
def cdf(muestra):
  n=len(muestra)
  x=np.sort(muestra)
  y=np.arange(0,n)/n
  return x,y

# %%
X,Y= cdf(G)

# %%
plt.step(X,Y)
