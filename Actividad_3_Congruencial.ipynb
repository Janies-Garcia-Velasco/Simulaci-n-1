# %% [markdown]
# <a href="https://colab.research.google.com/github/Janies-Garcia-Velasco/Simulaci-n-1/blob/main/Actividad_3_Congruencial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tabulate

# %%
import tabulate

x0=3#int(input("escriba un numero semilla: "))
a=13#int(input("escriba un valor para a "))
c=0#int(input("escriba un valor para c: "))
m=64#int(input("escriba un valor para m: "))
n=20


#lista
resultados=[]
#para la tabla
for i in range(n):

  funcion=(a*x0)+c

  funmod=funcion%m

  num_ale=x0/m


  #almacenar resultados en una lista
  resultados.append([i,x0,funcion,funmod,num_ale])

  x0=funmod

#para imprimir tabla
tabla=["N","Xn","resultado de funcion","modulo respecto m","cociente respecto m"]
print(tabulate.tabulate(resultados, headers=tabla, tablefmt="grid"))
# Out:
# +-----+------+------------------------+---------------------+-----------------------+
# |   N |   Xn |   resultado de funcion |   modulo respecto m |   cociente respecto m |
# +=====+======+========================+=====================+=======================+
# |   0 |    3 |                     39 |                  39 |              0.046875 |
# +-----+------+------------------------+---------------------+-----------------------+
# |   1 |   39 |                    507 |                  59 |              0.609375 |
# +-----+------+------------------------+---------------------+-----------------------+
# |   2 |   59 |                    767 |                  63 |              0.921875 |
# +-----+------+------------------------+---------------------+-----------------------+
# |   3 |   63 |                    819 |                  51 |              0.984375 |
# +-----+------+------------------------+---------------------+-----------------------+
# ...
